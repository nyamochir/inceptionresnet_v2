# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("history.csv")

# %%
data.index = data["epoch"]
data[["TrainingAccuracy", "ValidationAccurary"]].plot()
plt.title("Resnet50 Model on Action Recognition")
#plt.show()
plt.savefig("resnet_history.png")
